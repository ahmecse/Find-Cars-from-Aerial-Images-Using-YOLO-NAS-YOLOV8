# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
import os
if not os.path.isdir("yolov8session"):
  os.makedirs("yolov8session")

# %%
# %cd yolov8session
# Out:
# /content/gdrive/MyDrive/yolov8session

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# %cd ultralytics
# Out:
# /content/gdrive/MyDrive/yolov8session/ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.6/609.6 kB 7.9 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="1.jpeg"
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 431, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 246, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py", line 204, in predict_cli
# ...

# %%
# !yolo task=segment mode=predict source='5 (29)_1650425730.jpg'
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/5 (29)_1650425730.jpg: 640x576 1 train, 186.6ms
# Speed: 4.5ms preprocess, 186.6ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to runs/segment/predict12

# %%
# !yolo task=classify mode=predict source="5 (29)_1650425730.jpg"
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/5 (29)_1650425730.jpg: 224x224 spiny_lobster 0.24, tripod 0.03, little_blue_heron 0.02, black_and_gold_garden_spider 0.02, combination_lock 0.02, 8.3ms
# Speed: 6.0ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict11

# %%
# !yolo task=detect mode=predict source="1.mp4"
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# video 1/1 (1/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 12 persons, 2 backpacks, 1 handbag, 92.1ms
# video 1/1 (2/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 12 persons, 2 backpacks, 1 handbag, 7.7ms
# video 1/1 (3/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 12 persons, 2 backpacks, 1 handbag, 6.7ms
# video 1/1 (4/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 10 persons, 1 backpack, 2 handbags, 8.8ms
# video 1/1 (5/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 11 persons, 1 backpack, 3 handbags, 7.0ms
# video 1/1 (6/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 11 persons, 2 backpacks, 2 handbags, 7.2ms
# ...

# %%
# !yolo task=segment mode=predict source="1.mp4"
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients
#
# video 1/1 (1/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 14 persons, 2 backpacks, 1 handbag, 183.1ms
# video 1/1 (2/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 14 persons, 2 backpacks, 1 handbag, 10.1ms
# video 1/1 (3/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 14 persons, 2 backpacks, 1 handbag, 8.7ms
# video 1/1 (4/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 13 persons, 2 backpacks, 1 handbag, 12.3ms
# video 1/1 (5/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 12 persons, 2 backpacks, 1 handbag, 1 suitcase, 14.1ms
# video 1/1 (6/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 384x640 11 persons, 3 backpacks, 1 handbag, 13.9ms
# ...

# %%
# !yolo task=classify mode=predict source="1.mp4"
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients
#
# ...
# 100% 755k/755k [00:00<00:00, 41.3MB/s]
# video 1/1 (1/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 224x224 valley 0.13, Granny_Smith 0.12, wooden_spoon 0.08, lab_coat 0.07, carousel 0.05, 4.2ms
# video 1/1 (2/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 224x224 valley 0.13, Granny_Smith 0.12, wooden_spoon 0.08, lab_coat 0.07, carousel 0.05, 4.7ms
# video 1/1 (3/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 224x224 valley 0.13, Granny_Smith 0.12, wooden_spoon 0.08, lab_coat 0.07, carousel 0.05, 3.6ms
# video 1/1 (4/3493) /content/gdrive/MyDrive/yolov8session/ultralytics/1.mp4: 224x224 valley 0.22, Granny_Smith 0.16, lab_coat 0.06, wooden_spoon 0.05, carousel 0.05, 4.2ms
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=custom_data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.158 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt source="f1.jpeg"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 405, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 94, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 140, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 610, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 549, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 791, in load
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt source="f2.mp4"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 405, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 94, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 140, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 610, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 549, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 791, in load
# ...
